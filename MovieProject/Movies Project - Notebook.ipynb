# %% [markdown]
# # Movies Project - Notebook
# ## Nathaniel Auriel Wiradiradja
# ---

# %% [markdown]
# Importing Modules

# %%
import pandas as pd

# %% [markdown]
# Loading the data

# %%
data = pd.read_json("movies_dataset.json")
data
# Out:
#       color      director_name  num_critic_for_reviews  duration        gross  \
# 0     Color      James Cameron                   723.0     178.0  760505847.0
# 1     Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2     Color         Sam Mendes                   602.0     148.0  200074175.0
# 3     Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4       NaN        Doug Walker                     NaN       NaN          NaN
# ...     ...                ...                     ...       ...          ...
# 5038  Color        Scott Smith                     1.0      87.0          NaN
# 5039  Color                NaN                    43.0      43.0          NaN
# 5040  Color   Benjamin Roberds                    13.0      76.0          NaN
# 5041  Color        Daniel Hsia                    14.0     100.0      10443.0
# 5042  Color           Jon Gunn                    43.0      90.0      85222.0
#
# ...

# %% [markdown]
# Check the dataframe shape (#rows and #columns)

# %%
data.shape
# Out:
# (5043, 14)

# %% [markdown]
# Check the data types of the columns

# %%
data.dtypes
# Out:
# color                      object
# director_name              object
# num_critic_for_reviews    float64
# duration                  float64
# gross                     float64
# genres                     object
# star_name                  object
# movie_title                object
# movie_imdb_link            object
# language                   object
# country                    object
# budget                    float64
# title_year                float64
# imdb_score                float64
# dtype: object

# %% [markdown]
# Column Selection

# %%
data.genres
# Out:
# 0       Action|Adventure|Fantasy|Sci-Fi
# 1              Action|Adventure|Fantasy
# 2             Action|Adventure|Thriller
# 3                       Action|Thriller
# 4                           Documentary
#                      ...
# 5038                       Comedy|Drama
# 5039       Crime|Drama|Mystery|Thriller
# 5040              Drama|Horror|Thriller
# 5041               Comedy|Drama|Romance
# 5042                        Documentary
# Name: genres, Length: 5043, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Data Preparation
# Remove some columns:
#
#    - `movie_imdb_link`
#    - `num_critic_for_reviews`
#    - `genre`

# %%
data.drop(axis = 1, columns = ["movie_imdb_link"])

# %%
data
# Out:
#       color      director_name  duration  movie_income        star_name  \
# 0     Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN           NaN      Doug Walker
# ...     ...                ...       ...           ...              ...
# 5038  Color        Scott Smith      87.0           NaN      Eric Mabius
# 5039  Color                NaN      43.0           NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0           NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0       10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0       85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# Remove the rest of the columns

# %%
data.drop(axis = 1, columns = ["num_critic_for_reviews", "genres"])

# %%
data
# Out:
#       color      director_name  duration  movie_income        star_name  \
# 0     Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN           NaN      Doug Walker
# ...     ...                ...       ...           ...              ...
# 5038  Color        Scott Smith      87.0           NaN      Eric Mabius
# 5039  Color                NaN      43.0           NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0           NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0       10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0       85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# Check the shape again

# %%
data.shape
# Out:
# (5043, 11)

# %% [markdown]
# Convert the dtype of `title_year` column to integer

# %%
data.title_year = data.title_year.astype("Int64")
data.title_year
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       <NA>
#         ...
# 5038    2013
# 5039    <NA>
# 5040    2013
# 5041    2012
# 5042    2004
# Name: title_year, Length: 5043, dtype: Int64

# %% [markdown]
# Check the dataframe again

# %%
data
# Out:
#       color      director_name  duration        gross        star_name  \
# 0     Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN          NaN      Doug Walker
# ...     ...                ...       ...          ...              ...
# 5038  Color        Scott Smith      87.0          NaN      Eric Mabius
# 5039  Color                NaN      43.0          NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0          NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0      10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0      85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# Renaming some columns:
# - changing `gross` to `movie_income`

# %%
rename_dict = {"gross" : "movie_income"}
data.rename(columns = rename_dict, inplace = True)
data
# Out:
#       color      director_name  duration  movie_income        star_name  \
# 0     Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN           NaN      Doug Walker
# ...     ...                ...       ...           ...              ...
# 5038  Color        Scott Smith      87.0           NaN      Eric Mabius
# 5039  Color                NaN      43.0           NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0           NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0       10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0       85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# Rename the `budget` column to `movie_budget`

# %%
rename_dict = {"budget" : "movie_budget"}
data.rename(columns = rename_dict, inplace = True)
data
# Out:
#       color      director_name  duration  movie_income        star_name  \
# 0     Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN           NaN      Doug Walker
# ...     ...                ...       ...           ...              ...
# 5038  Color        Scott Smith      87.0           NaN      Eric Mabius
# 5039  Color                NaN      43.0           NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0           NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0       10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0       85222.0      John August
#
#                                      movie_title language country  \
# ...

# %% [markdown]
# ---
# ### Data Analysis
#
#
# Checking the distribution of `duration` column using a histogram.

# %%
data.head(3)
# Out:
#    color   director_name  duration  movie_income        star_name  \
# 0  Color   James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color  Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color      Sam Mendes     148.0   200074175.0  Christoph Waltz
#
#                                 movie_title language country  movie_budget  \
# 0                                    Avatar  English     USA   237000000.0
# 1  Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 2                                   Spectre  English      UK   245000000.0
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# 2        2015         6.8

# %%
ax = data.duration.hist(bins = 20, figsize = (8,6), grid = False)
ax.set_xlabel("Movie Durations (In minutes)")
ax.set_ylabel("Count")
ax.set_title("Movie Duration Histogram")
# Out:
# Text(0.5, 1.0, 'Movie Duration Histogram')

# %% [markdown]
# Creating a histogram to see the distribution of `imdb_score` column

# %%
ax = data.imdb_score.hist(bins = 25, figsize = (10,8), grid = False)
ax.set_xlabel("Score")
ax.set_ylabel("Count")
ax.set_title("Movies IMDB Score")
# Out:
# Text(0.5, 1.0, 'Movies IMDB Score')

# %% [markdown]
# Checking how many movies have the `imdb_score` less than `4`.

# %%
low_score = data[data.imdb_score < 4]
low_score
# Out:
#       color       director_name  duration  movie_income        star_name  \
# 217   Color     Joel Schumacher     125.0   107285004.0    Michael Gough
# 267   Color         Jan de Bont     121.0    48068396.0     Jason Patric
# 273   Color            Bo Welch      82.0   100446895.0       Sean Hayes
# 313   Color               Pitof      87.0    40198710.0   Frances Conroy
# 319   Color   Lawrence Guterman      94.0    17010646.0    Jamie Kennedy
# ...     ...                 ...       ...           ...              ...
# 4988  Color   Terron R. Parsons      93.0           NaN    Richard Tyson
# 5000  Color        Travis Legge      83.0           NaN   Elissa Dowling
# 5002  Color  Collin Joseph Neal      75.0           NaN  Julianne Gabert
# 5017  Color        Travis Legge      90.0           NaN   Kristen Seavey
# 5020    NaN     Brandon Landers     143.0           NaN    Robbie Barnes
#
#                   movie_title language country  movie_budget  title_year  \
# ...

# %%
low_score.shape
# Out:
# (156, 11)

# %% [markdown]
# Use a histogram to visualize the distribution of movie IMdb score in that are produced in `USA`.

# %%
ax = data[data.country == "USA"].imdb_score.hist(bins = 25, grid = False) 
ax.set_xlabel("Movie Rating (USA)")
ax.set_ylabel("Count")
ax.set_title("IMDB Scores for Movies Produced in USA")
# Out:
# Text(0.5, 1.0, 'IMDB Scores for Movies Produced in USA')

# %% [markdown]
# ---
# ### Further Analysis
#
# #### Finding in which year we have the `highest` and `lowest` number of movies

# %% [markdown]
# Finding out number of movies per year

# %%
count_per_year = data.groupby("title_year").size()
count_per_year
# Out:
# title_year
# 1916      1
# 1920      1
# 1925      1
# 1927      1
# 1929      2
#        ...
# 2012    221
# 2013    237
# 2014    252
# 2015    226
# 2016    106
# Length: 91, dtype: int64

# %% [markdown]
# Creating a line chart to show the result

# %%
ax = count_per_year.plot(figsize = (8,6))
ax.set_xlabel("Years")
ax.set_ylabel("Movie Count")
ax.set_title("Distribution of Movies Through the Years")
# Out:
# Text(0.5, 1.0, 'Distribution of Movies Through the Years')

# %% [markdown]
# #### Finding in which year we have `minimum` and `maximum` average `imdb_score`

# %% [markdown]
# Finding average imdb score per year

# %%
avg = data.groupby("title_year")['imdb_score'].mean()
avg
# Out:
# title_year
# 1916    8.000000
# 1920    4.800000
# 1925    8.300000
# 1927    8.300000
# 1929    7.150000
#           ...
# 2012    6.266516
# 2013    6.369620
# 2014    6.228175
# 2015    6.033628
# 2016    6.399057
# Name: imdb_score, Length: 91, dtype: float64

# %% [markdown]
# Using a barchart to visualize the result

# %%
ax = avg.plot.bar(figsize = (18,8), title = "Average IMDB score per Year")
ax.set_xlabel("Years")
ax.set_ylabel("Score")
# Out:
# Text(0, 0.5, 'Score')

# %% [markdown]
# Finding In which year we have the `minimum` and `maximum` spent movie budget?

# %%
ax = data.groupby("title_year")["movie_budget"].sum().plot()
ax.set_xlabel("Year")
ax.set_ylabel("Budget")
ax.set_title("Movie Budget through the Years")
# Out:
# Text(0.5, 1.0, 'Movie Budget through the Years')

# %% [markdown]
# Correlation between IMdb score of a movie and the movie income
#
# To approach this
# - Visual Correlation Analysis
# - Generating the Correlation Matirx

# %%
data_corr = data[["imdb_score", "movie_income"]]
data_corr
# Out:
#       imdb_score  movie_income
# 0            7.9   760505847.0
# 1            7.1   309404152.0
# 2            6.8   200074175.0
# 3            8.5   448130642.0
# 4            7.1           NaN
# ...          ...           ...
# 5038         7.7           NaN
# 5039         7.5           NaN
# 5040         6.3           NaN
# 5041         6.3       10443.0
# 5042         6.6       85222.0
#
# [5043 rows x 2 columns]

# %% [markdown]
# Dropping the rows with `non` values

# %%
data_corr.dropna(inplace=True)
# Out:
# C:\Users\Nate\AppData\Local\Temp\ipykernel_18924\2321171656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_corr.dropna(inplace=True)

# %% [markdown]
# Creating a scatter plot to see the data

# %%
ax = data_corr.plot.scatter(x = "movie_income", y = "imdb_score", figsize = (10,10))
ax.set_xlabel("Movie Income")
ax.set_ylabel("Score")
ax.set_title("Correlation Between Movie Income and it's Score")
# Out:
# Text(0.5, 1.0, "Correlation Between Movie Income and it's Score")

# %% [markdown]
# Generating the correlation matrix

# %%
data_corr.corr()
# Out:
#               imdb_score  movie_income
# imdb_score      1.000000      0.198021
# movie_income    0.198021      1.000000
